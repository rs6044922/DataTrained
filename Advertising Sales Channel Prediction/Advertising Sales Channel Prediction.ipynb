# %% [markdown]
# # Sales Data Set
# ## Loading data

# %%
#importing basic library
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sn

import warnings 
warnings.filterwarnings('ignore')

# %%
#loading the data file and displaying the top 5 rows
df=pd.read_csv('Salesdataset.csv')
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#Displaying the bottom 5 rows
df.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
#Displaying all the column names 
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
#Displaying the number of rows and columns present in the data set
df.shape
# Out:
# (200, 5)

# %%
#Displaying data type of each column
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
#Checking the value counts of each attribute
for i in df.columns:
    print(f"Column: {i}")
    print(df[i].value_counts())
    print('\n\n')
# Out:
# Column: Unnamed: 0
# 200    1
# 63     1
# 73     1
# 72     1
# 71     1
#       ..
# 131    1
# 130    1
# 129    1
# 128    1
# 1      1
# Name: Unnamed: 0, Length: 200, dtype: int64
#
#
#
# Column: TV
# 197.6    2
# 237.4    2
# 177.0    2
# 76.4     2
# 222.4    2
#         ..
# 18.8     1
# 19.4     1
# 26.8     1
# 139.2    1
# 44.5     1
# Name: TV, Length: 190, dtype: int64
#
#
#
# Column: radio
# 5.7     3
# 4.1     3
# 26.7    2
# 18.1    2
# 43.0    2
#        ..
# 37.6    1
# 26.9    1
# 40.6    1
# 34.3    1
# 24.0    1
# Name: radio, Length: 167, dtype: int64
#
#
#
# Column: newspaper
# 8.7     3
# 25.6    3
# 9.3     3
# 14.2    2
# 45.1    2
#        ..
# 43.1    1
# 49.3    1
# 31.3    1
# 44.3    1
# 58.5    1
# Name: newspaper, Length: 172, dtype: int64
#
#
#
# Column: sales
# 9.7     5
# 12.9    4
# 11.7    4
# 15.9    4
# 25.4    3
#        ..
# 15.7    1
# 14.2    1
# 11.2    1
# 19.4    1
# 18.5    1
# Name: sales, Length: 121, dtype: int64

# %%
#Checking for Max and Min value of each attribute
for i in df.columns:
    print('Column: ',i)
    print(df[i].min())
    print(df[i].max(),'\n\n')
# Out:
# Column:  Unnamed: 0
# 1
# 200
#
#
# Column:  TV
# 0.7
# 296.4
#
#
# Column:  radio
# 0.0
# 49.6
#
#
# Column:  newspaper
# 0.3
# 114.0
#
#
# Column:  sales
# 1.6
# 27.0

# %%
#looking at the statistical data set 
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ## Univariate analysis

# %%
#ploting box plot for all numeric column
plt.figure(figsize=(5,15))
a=df.columns
for i in range(0,len(a)):
    plt.subplot(5,1,i+1)
    sn.boxplot(y=a[i],color='yellow',data=df)
    plt.tight_layout()

# %%
#ploting distribution curve for all the columns
plt.figure(figsize=(5,15))
a=df.columns
enumerate(a)
for i,name in enumerate(a):
    plt.subplot(5,1,i+1)
    sn.distplot(df[name],color='Red')
    plt.tight_layout()

# %% [markdown]
# ## Bivariate analysis

# %%
#ploatong the scatter plot of sales v/s TV
sn.set(style="whitegrid")
sn.scatterplot(x='TV',y='sales',data=df,color='g')
# Out:
# <AxesSubplot:xlabel='TV', ylabel='sales'>

# %%
#ploatong the scatter plot of sales v/s radio
sn.set(style="whitegrid")
sn.scatterplot(x='radio',y='sales',data=df,color='deeppink')
# Out:
# <AxesSubplot:xlabel='radio', ylabel='sales'>

# %%
#ploatong the scatter plot of sales v/s newspaper
sn.set(style="whitegrid")
sn.scatterplot(x='newspaper',y='sales',data=df,color='dodgerblue')
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='sales'>

# %%
#ploting pair plot for our data set
sn.pairplot(df)

# %% [markdown]
# ## Multi variate analysis

# %%
#ploting heat map to see wheather null value is present or not
sn.heatmap(df.isnull(),cmap='YlOrBr')
# Out:
# <AxesSubplot:>

# %%
#seeing correlation of each parameter with label column
cor=df.corr()
cor
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
#plotting correlation value of each attribute with sales
plt.figure(figsize=(22,7))
df.corr()['sales'].sort_values(ascending=False).drop(['sales']).plot(kind='bar',color='g')
plt.xlabel('Attributes',fontsize=18)
plt.ylabel('Corr value with sales',fontsize=18)
plt.title('correlation',fontsize=18)
plt.show()

# %%
#ploting heat map for correlation matrix
sn.heatmap(cor,cmap='gist_rainbow',annot=True,linewidth=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data cleaning
# ## Outlier removal

# %%
#removing outlier by z score method
print("Before removing outliers::",df.shape)
from scipy.stats import zscore
z=zscore(df)
df=df[(z<3).all(axis=1)]
print("After removing outliers::",df.shape)
# Out:
# Before removing outliers:: (200, 5)
# After removing outliers:: (198, 5)

# %% [markdown]
# ## Removing skewness

# %%
#checking skewness
df.skew()
# Out:
# Unnamed: 0   -0.006283
# TV           -0.082332
# radio         0.114842
# newspaper     0.650112
# sales         0.407130
# dtype: float64

# %%
#removing using boxcox
from scipy.stats import boxcox
df['newspaper']=np.sqrt(df['newspaper'])

# %%
#checking the skewness after removing the skewness
df.skew()
# Out:
# Unnamed: 0   -0.006283
# TV           -0.082332
# radio         0.114842
# newspaper    -0.040649
# sales         0.407130
# dtype: float64

# %% [markdown]
# ## Creating X and Y

# %%
x=df.drop('sales',axis=1)
y=df['sales']

# %% [markdown]
# ## Model building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
from sklearn.model_selection import cross_val_score
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Selecting best random state

# %%
#selecting best random classifier
maxAccu=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    r2=r2_score(y_test,pred)
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i
print('Best accuracy is ',maxAccu,' on random state ',maxRS)
# Out:
# Best accuracy is  0.9359096421813846  on random state  90

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=90)

# %% [markdown]
# ## LinearRegression

# %%
#building model using LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
pred=lm.predict(x_test)
r2=r2_score(y_test,pred)
print(r2)
# Out:
# 0.9082149729801556

# %%
#cross validation of LinearRegression
print(cross_val_score(lm,x,y,cv=5).mean())
# Out:
# 0.8831072487910128

# %% [markdown]
# ## RandomForestRegressor

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
import warnings
from sklearn.model_selection import cross_val_score
warnings.filterwarnings('ignore')

# %%
#building model using RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
rfg=RandomForestRegressor()
rfg.fit(x_train,y_train)
pred=lm.predict(x_test)
r2=r2_score(y_test,pred)
print(r2)
# Out:
# 0.9082149729801556

# %%
#cross validation of RandomForestRegressor
print(cross_val_score(rfg,x,y,cv=5).mean())
# Out:
# 0.9733691641534014

# %% [markdown]
# ## DecisionTreeRegressor

# %%
#building model using DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=lm.predict(x_test)
r2=r2_score(y_test,pred)
print(r2)
# Out:
# 0.9082149729801556

# %%
#cross validation of DecisionTreeRegressor
print(cross_val_score(dtr,x,y,cv=5).mean())
# Out:
# 0.9486507256399215

# %% [markdown]
# # HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression

parameters={'normalize':['True'],'n_jobs':[4]}
l_r=LinearRegression()
clf=GridSearchCV(l_r,parameters)
clf.fit(x_test,y_test)
print(clf.best_params_)
# Out:
# {'n_jobs': 4, 'normalize': 'True'}

# %%
#tuning on LinearRegression
Final_mod=LinearRegression(n_jobs=4,normalize=True)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
r2=r2_score(y_test,pred)
print(r2)
# Out:
# 0.9082149729801557

# %%
#cross validation of RandomForestRegressor
print(cross_val_score(Final_mod,x,y,cv=5).mean())
# Out:
# 0.8831072487910128

# %% [markdown]
# After hyper parameter the r2 and cross validation both are same
# so saving Final model
# which has 90 % accuracy

# %% [markdown]
# # Saving the Model

# %%
#saving the model
import joblib
joblib.dump(Final_mod,'FinalModel.pkl')
# Out:
# ['FinalModel.pkl']
