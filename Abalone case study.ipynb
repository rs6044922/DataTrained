# %% [markdown]
# # Abalone case study
#
# # Data Collection

# %%
#importing all the basic laibrary
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

import warnings 
warnings.filterwarnings('ignore')

# %%
#loading the data file and displaying the top 5 rows of data file
df=pd.read_csv('Abalone.csv')
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
#displaying the column names
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
#displaying the number of rows and columns present in our data set
df.shape
# Out:
# (4177, 9)

# %%
#displaying the column names and the data type present in there respective column
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
#checking wheather null value is present or not 
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
#Checking the value counts of each attribute
for attr in df.columns:
    print("\n",attr)
    print(df[attr].value_counts())
# Out:
#  Sex
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64
#
#  Length
# 0.625    94
# 0.550    94
# 0.575    93
# 0.580    92
# 0.620    87
#          ..
# 0.150     1
# 0.110     1
# 0.135     1
# 0.800     1
# 0.815     1
# Name: Length, Length: 134, dtype: int64
#
#  Diameter
# 0.450    139
# 0.475    120
# 0.400    111
# 0.500    110
# 0.470    100
#         ...
# 0.615      1
# 0.620      1
# 0.625      1
# 0.090      1
# 0.095      1
# Name: Diameter, Length: 111, dtype: int64
#
#  Height
# 0.150    267
# 0.140    220
# 0.155    217
# 0.175    211
# 0.160    205
# 0.125    202
# 0.165    193
# 0.135    189
# 0.145    182
# 0.130    169
# 0.120    169
# 0.170    160
# 0.100    145
# 0.110    135
# 0.115    133
# 0.180    131
# 0.090    124
# 0.105    114
# 0.185    103
# 0.190    103
# 0.095     91
# 0.195     78
# 0.080     76
# 0.085     74
# 0.200     68
# 0.075     61
# 0.070     47
# 0.205     45
# 0.065     39
# 0.215     31
# 0.060     26
# 0.055     25
# ...

# %%
for column in df.columns:
    print(f"=======Column: {column}=======")
    print(f"Number of unique values: {df[column].nunique()}")
    print(f"Max: {df[column].max()}")
    print(f"Min: {df[column].min()}")
# Out:
# =======Column: Sex=======
# Number of unique values: 3
# Max: M
# Min: F
# =======Column: Length=======
# Number of unique values: 134
# Max: 0.815
# Min: 0.075
# =======Column: Diameter=======
# Number of unique values: 111
# Max: 0.65
# Min: 0.055
# =======Column: Height=======
# Number of unique values: 51
# Max: 1.13
# Min: 0.0
# =======Column: Whole weight=======
# Number of unique values: 2429
# Max: 2.8255
# Min: 0.002
# =======Column: Shucked weight=======
# Number of unique values: 1515
# Max: 1.4880000000000002
# Min: 0.001
# =======Column: Viscera weight=======
# Number of unique values: 880
# Max: 0.76
# Min: 0.0005
# =======Column: Shell weight=======
# Number of unique values: 926
# Max: 1.005
# Min: 0.0015
# =======Column: Rings=======
# Number of unique values: 28
# Max: 29
# Min: 1

# %%
#looking at the statistical information of our data set 
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# 1) We can see that data has 9 column and 4177 rows
# 2) column are either float, int and object data type
# 3) There is no missing value
# 4) There is no null value
# 5) 8 columns has continious value amd 1 has classification valur
# 6) There is no negative values
# 7) Some outlier and skewness present

# %% [markdown]
# ## Univariate analysis

# %%
#ploting box plot for all the column
fig, ((ax1, ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9)) = plt.subplots(nrows=3, ncols=3, figsize = (20, 20))
sn.boxplot(df['Length'] , color="dodgerblue",ax=ax2)
sn.boxplot(df['Diameter'] , color="g",ax=ax3)
sn.boxplot(df['Height'] , color="r",ax=ax4)
sn.boxplot(df['Whole weight'] , color="dodgerblue",ax=ax5)
sn.boxplot(df['Shucked weight'] , color="deeppink",ax=ax6)
sn.boxplot(df['Viscera weight'] , color="gold",ax=ax7)
sn.boxplot(df['Shell weight'] , color="dodgerblue",ax=ax8)
sn.boxplot(df['Rings'] , color="deeppink",ax=ax9)
# Out:
# <AxesSubplot:xlabel='Rings'>

# %%
#ploting distribution curve for all the columns
df.plot(kind='density',subplots=True,layout=(3,3),sharex=False,fontsize=1,figsize=(20,20))
plt.show()

# %% [markdown]
# We can see 1) Outlier is present in all columns 2) Slight skewness is present in all columns

# %%
#ploating countplpot for Sex column
sn.countplot(x='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
#  We can see data balance in quality column

# %% [markdown]
# ## Bivariate analysis

# %%
#ploting scatter plot between 'Rings'and 'Sex'
sn.scatterplot(x='Rings',y='Sex',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Sex'>

# %% [markdown]
# Column Rings and sex have no such relation

# %%
#ploting scatter plot between 'Rings'and 'Length'
sn.scatterplot(x='Rings',y='Length',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Length'>

# %% [markdown]
# Column Rings and Length have posotive relation but its too much scattered

# %%
#ploting scatter plot between 'Rings'and 'Diameter'
sn.scatterplot(x='Rings',y='Diameter',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Diameter'>

# %% [markdown]
# Column Rings and Diameter have posotive relation but its too much scattered

# %%
#ploting scatter plot between 'Rings'and 'Height'
sn.scatterplot(x='Rings',y='Height',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Height'>

# %% [markdown]
# Column Rings and Height have posotive relation

# %%
#ploting scatter plot between 'Rings'and 'Whole weight'
sn.scatterplot(x='Rings',y='Whole weight',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Whole weight'>

# %%
#ploting scatter plot between 'Rings'and 'Shucked weight'
sn.scatterplot(x='Rings',y='Shucked weight',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Shucked weight'>

# %%
#ploting scatter plot between 'Rings'and 'Viscera weight'
sn.scatterplot(x='Rings',y='Viscera weight',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Viscera weight'>

# %%
#ploting scatter plot between 'Rings'and 'Shell weight'
sn.scatterplot(x='Rings',y='Shell weight',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Shell weight'>

# %% [markdown]
# We cant get much reation of column Whole weight, Shucked weight, Viscera weight, Shell weight with Rings

# %% [markdown]
# We can see that infant abalone has less values in each column

# %%
sn.pairplot(df,hue='Sex')

# %% [markdown]
# ## Multi variate analysis

# %%
#ploting heat map to see wheather null value is present or not
sn.heatmap(df.isnull(),cmap='YlOrBr')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see no null value is present

# %%
#seeing correlation of each parameter with label column
df_Cor=df.corr()
df_Cor
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
#plotting correlation value of each attribute with Rings 
plt.figure(figsize=(22,7))
df.corr()['Rings'].sort_values(ascending=False).drop(['Rings']).plot(kind='bar',color='c')
plt.xlabel('Attributes',fontsize=18)
plt.ylabel('Corr value with ring',fontsize=18)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Shell weight has highest correlation with Rings
# Shucked weight has lowest correlation with Rings

# %%
#ploting heat map for correlation matrix
plt.figure(figsize=(10,10))
sn.heatmap(df_Cor,annot=True,cmap='RdPu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data cleaning
# ## Encoding

# %%
#converting sex column into float data type
from sklearn.preprocessing import OrdinalEncoder

enc=OrdinalEncoder()
df['Sex']=enc.fit_transform(df['Sex'].values.reshape(-1,1))

# %% [markdown]
# ## Outlier removal

# %%
#removing outlier by z score method
from scipy.stats import zscore
z=zscore(df)
df_new=df[(z<3).all(axis=1)]
print("Before removing outliers::",df.shape)
print("After removing outliers::",df_new.shape)
# Out:
# Before removing outliers:: (4177, 9)
# After removing outliers:: (4046, 9)

# %% [markdown]
# ## Skewness removal

# %%
#checking skewness  
df_new.skew()
# Out:
# Sex              -0.095167
# Length           -0.681262
# Diameter         -0.648037
# Height           -0.313924
# Whole weight      0.329684
# Shucked weight    0.453702
# Viscera weight    0.432857
# Shell weight      0.342641
# Rings             0.687987
# dtype: float64

# %% [markdown]
# Removing skewness from column Length and Diameter by log transfer

# %%
df_new['Length']=np.log(df_new['Length'])

# %%
df_new['Diameter']=np.log(df_new['Diameter'])

# %%
#spliting into X and Y
x=df_new.drop(['Rings'],axis=1)
y=df_new['Rings']

# %% [markdown]
# ## Importing library for model building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# ## Finding best random state

# %%
#selecting best random classifier
maxAccu=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    r2=r2_score(y_test,pred)
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i
print('Best accuracy is ',maxAccu,' on random state ',maxRS)
# Out:
# Best accuracy is  0.5676922946041003  on random state  36

# %% [markdown]
# ## Train test split

# %%
#train, test, split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=36)

# %%
import warnings
from sklearn.model_selection import cross_val_score
warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# ## LinearRegression

# %%
#building model using LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
pred=lm.predict(x_test)
r2=r2_score(y_test,pred)
print(r2)
# Out:
# 0.5667705413198931

# %%
#cross validation of LinearRegression
print(cross_val_score(lm,x,y,cv=5).mean())
# Out:
# 0.4305626918432669

# %% [markdown]
# ## RandomForestRegressor

# %%
#building model using RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
rfg=RandomForestRegressor()
rfg.fit(x_train,y_train)
pred=lm.predict(x_test)
r2=r2_score(y_test,pred)
print(r2)
# Out:
# 0.5667705413198931

# %%
#cross validation of RandomForestRegressor
print(cross_val_score(rfg,x,y,cv=5).mean())
# Out:
# 0.46234451776389723

# %% [markdown]
# ## Decision Tree Regressor

# %%
#building model using DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=lm.predict(x_test)
r2=r2_score(y_test,pred)
print(r2)
# Out:
# 0.5667705413198931

# %%
#cross validation of DecisionTreeRegressor
print(cross_val_score(dtr,x,y,cv=5).mean())
# Out:
# -0.05940121462323544

# %% [markdown]
# I am selecting Random forest regressor as my model as if havs less difference between r2score and cross validation

# %% [markdown]
# # HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_test,y_test)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
#tuning on RandomForestRegressor
Final_mod=RandomForestRegressor(criterion='mae',max_features='auto')
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)

# %%
r2=r2_score(y_test,pred)
print(r2)
# Out:
# 0.5854457258245579

# %%
#cross validation of RandomForestRegressor
print(cross_val_score(Final_mod,x,y,cv=5).mean())
# Out:
# 0.4590886676545085

# %% [markdown]
# After HYPER PARAMETER TUNING of my Random Forest Regressor model r2score has increased to 58% so I am saving that model.

# %% [markdown]
# # Saving the Model

# %%
#saving the model
import joblib
joblib.dump(Final_mod,'FinalModel.pkl')
# Out:
# ['FinalModel.pkl']
